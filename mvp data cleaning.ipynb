# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
mvp_file ="NBA Finals and MVP.xlsx"
mvp_df = pd.read_excel(mvp_file)
mvp_df
# Out:
#     Year       Western Champion     Eastern Champion Result  \
# 0   1950     Minneapolis Lakers   Syracuse Nationals    4–2
# 1   1951       Rochester Royals      New York Knicks    4–3
# 2   1952     Minneapolis Lakers      New York Knicks    4–3
# 3   1953     Minneapolis Lakers      New York Knicks    4–1
# 4   1954     Minneapolis Lakers   Syracuse Nationals    4–3
# ..   ...                    ...                  ...    ...
# 64  2014      San Antonio Spurs           Miami Heat    4–1
# 65  2015  Golden State Warriors  Cleveland Cavaliers    4–2
# 66  2016  Golden State Warriors  Cleveland Cavaliers    4–3
# 67  2017  Golden State Warriors  Cleveland Cavaliers    4-2
# 68  2018  Golden State Warriors  Cleveland Cavaliers    4-0
#
#              NBA Champion      NBA Vice-Champion  Final Sweep ?  \
# 0      Minneapolis Lakers     Syracuse Nationals          False
# 1        Rochester Royals        New York Knicks          False
# ...

# %%
df_drop=mvp_df.iloc[6:]
df_drop
# Out:
#     Year       Western Champion       Eastern Champion Result  \
# 6   1956     Fort Wayne Pistons  Philadelphia Warriors    1–4
# 7   1957        St. Louis Hawks         Boston Celtics    3–4
# 8   1958        St. Louis Hawks         Boston Celtics    4–2
# 9   1959     Minneapolis Lakers         Boston Celtics    0–4
# 10  1960        St. Louis Hawks         Boston Celtics    3–4
# ..   ...                    ...                    ...    ...
# 64  2014      San Antonio Spurs             Miami Heat    4–1
# 65  2015  Golden State Warriors    Cleveland Cavaliers    4–2
# 66  2016  Golden State Warriors    Cleveland Cavaliers    4–3
# 67  2017  Golden State Warriors    Cleveland Cavaliers    4-2
# 68  2018  Golden State Warriors    Cleveland Cavaliers    4-0
#
#              NBA Champion      NBA Vice-Champion  Final Sweep ?  \
# 6   Philadelphia Warriors     Fort Wayne Pistons          False
# 7          Boston Celtics        St. Louis Hawks          False
# ...

# %%
new_mvp_df =df_drop[['MVP Frist_Name', 'MVP Last_Name','Year','MVP Position','MVP Team','MVP Nationality','MVP status']].copy()
new_mvp_df.head()
# Out:
#    MVP Frist_Name MVP Last_Name  Year MVP Position               MVP Team  \
# 6             Bob        Pettit  1956      Forward      Saint Louis Hawks
# 7             Bob         Cousy  1957        Guard         Boston Celtics
# 8            Bill       Russell  1958       Center         Boston Celtics
# 9             Bob        Pettit  1959      Forward      Saint Louis Hawks
# 10           Wilt   Chamberlain  1960       Center  Philadelphia Warriors
#
#    MVP Nationality         MVP status
# 6               US  Not reached Final
# 7               US           Champion
# 8               US      Vice-Champion
# 9               US  Not reached Final
# 10              US  Not reached Final

# %%
mvp = new_mvp_df.rename(columns={                                
                                 "MVP Position": "MVP_Position",
                                 "MVP Team": "MVP_team",
                                "MVP Nationality":"MVP_nationality",
                                 "MVP status":"MVP_status"
                                })
mvp.head()
# Out:
#    MVP Frist_Name MVP Last_Name  Year MVP_Position               MVP_team  \
# 6             Bob        Pettit  1956      Forward      Saint Louis Hawks
# 7             Bob         Cousy  1957        Guard         Boston Celtics
# 8            Bill       Russell  1958       Center         Boston Celtics
# 9             Bob        Pettit  1959      Forward      Saint Louis Hawks
# 10           Wilt   Chamberlain  1960       Center  Philadelphia Warriors
#
#    MVP_nationality         MVP_status
# 6               US  Not reached Final
# 7               US           Champion
# 8               US      Vice-Champion
# 9               US  Not reached Final
# 10              US  Not reached Final

# %%
team =

# %%
connection = "postgres:root123@localhost:5432/NBAdatabase"
engine = create_engine(f'postgresql://{connection}')

# %%
engine.table_names()
# Out:
# ['player_stats_2017',
#  'player_stats_2018',
#  'mvp',
#  'team',
#  'hall_of_fame_player',
#  'player',
#  'player_stats_2016']

# %%
# Uploading players information into Player_info table


mvp.to_sql('MVP_db', con = engine, if_exists = 'append', index = False)

# %%
team=pd.read_csv("Resources/TeamDetails.csv")
team
# Out:
#        team_id abbreviation      team_name  year_founded yearactive_till  \
# 0   1610612737          ATL          Hawks          1949         present
# 1   1610612737          ATL          Hawks          1949         present
# 2   1610612738          BOS        Celtics          1946         present
# 3   1610612739          CLE      Cavaliers          1970         present
# 4   1610612740          NOP       Pelicans          2002         present
# 5   1610612741          CHI          Bulls          1966         present
# 6   1610612742          DAL      Mavericks          1980         present
# 7   1610612743          DEN        Nuggets          1976         present
# 8   1610612744          GSW       Warriors          1946         present
# 9   1610612745          HOU        Rockets          1967         present
# 10  1610612746          LAC       Clippers          1970         present
# 11  1610612747          LAL         Lakers          1948         present
# ...

# %%
test="Bulls"
for team_to_check in mvp['MVP_team']:
    for row_in_master_data in team['team_name']:
        if row_in_master_data in team_to_check:
            mvp['team_id']=team['team_id']

# %%
mvp.tail()
# Out:
#    MVP Frist_Name MVP Last_Name  Year MVP_Position               MVP_team  \
# 64          Kevin        Durant  2014      Forward  Oklahoma City Thunder
# 65        Stephen         Curry  2015        Guard  Golden State Warriors
# 66        Stephen         Curry  2016        Guard  Golden State Warriors
# 67        Russell     Westbrook  2017        Guard  Oklahoma City Thunder
# 68          James        Harden  2018        Guard        Houston Rockets
#
#    MVP_nationality         MVP_status  team_id
# 64              US  Not reached Final      NaN
# 65              US           Champion      NaN
# 66              US      Vice-Champion      NaN
# 67              US  Not reached Final      NaN
# 68              US  Not reached Final      NaN
