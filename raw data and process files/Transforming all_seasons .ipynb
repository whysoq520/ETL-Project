# %%
import pandas as pd

# %%
nba_file = "all_seasons.csv"
nba_df = pd.read_csv(nba_file)
nba_df.head()
# Out:
#    Unnamed: 0      player_name team_abbreviation   age  player_height  \
# 0           0   Chris Robinson               VAN  23.0         195.58
# 1           1        Matt Fish               MIA  27.0         210.82
# 2           2     Matt Bullard               HOU  30.0         208.28
# 3           3     Marty Conlon               BOS  29.0         210.82
# 4           4  Martin Muursepp               DAL  22.0         205.74
#
#    player_weight                    college country draft_year draft_round  \
# 0       90.71840           Western Kentucky     USA       1996           2
# 1      106.59412  North Carolina-Wilmington     USA       1992           2
# 2      106.59412                       Iowa     USA  Undrafted   Undrafted
# 3      111.13004                 Providence     USA  Undrafted   Undrafted
# 4      106.59412                       None     USA       1996           1
#
#    ...  pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# ...

# %%
nba_df[['first_name','last_name']] = nba_df['player_name'].loc[nba_df['player_name'].str.split()
                                                               .str.len() == 2].str.split(expand=True)

nba_df.head()
# Out:
#    Unnamed: 0      player_name team_abbreviation   age  player_height  \
# 0           0   Chris Robinson               VAN  23.0         195.58
# 1           1        Matt Fish               MIA  27.0         210.82
# 2           2     Matt Bullard               HOU  30.0         208.28
# 3           3     Marty Conlon               BOS  29.0         210.82
# 4           4  Martin Muursepp               DAL  22.0         205.74
#
#    player_weight                    college country draft_year draft_round  \
# 0       90.71840           Western Kentucky     USA       1996           2
# 1      106.59412  North Carolina-Wilmington     USA       1992           2
# 2      106.59412                       Iowa     USA  Undrafted   Undrafted
# 3      111.13004                 Providence     USA  Undrafted   Undrafted
# 4      106.59412                       None     USA       1996           1
#
#    ...  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# ...

# %%
# Create a filtered dataframe from specific columns
player_columns = ["first_name", "last_name", "age", "player_weight", "player_height", "college","country", "season", "gp", 
               "pts", "reb", "ast"]

nba_transformed = nba_df[player_columns].copy()

# %%
nba_transformed.head()
# Out:
#   first_name last_name   age  player_weight  player_height  \
# 0      Chris  Robinson  23.0       90.71840         195.58
# 1       Matt      Fish  27.0      106.59412         210.82
# 2       Matt   Bullard  30.0      106.59412         208.28
# 3      Marty    Conlon  29.0      111.13004         210.82
# 4     Martin  Muursepp  22.0      106.59412         205.74
#
#                      college country   season  gp  pts  reb  ast
# 0           Western Kentucky     USA  1996-97  41  4.6  1.7  1.6
# 1  North Carolina-Wilmington     USA  1996-97   6  0.3  0.8  0.0
# 2                       Iowa     USA  1996-97  71  4.5  1.6  0.9
# 3                 Providence     USA  1996-97  74  7.8  4.4  1.4
# 4                       None     USA  1996-97  42  3.7  1.6  0.5

# %%
# Rename the column headers
final_nba_df = nba_transformed.rename(columns={"gp": "games_played",
                                                  "pts": "points",
                                                  "rb": "rebounds",
                                                  "ast": "assistance_pergame"})

# %%
final_nba_df.head()
# Out:
#   first_name last_name   age  player_weight  player_height  \
# 0      Chris  Robinson  23.0       90.71840         195.58
# 1       Matt      Fish  27.0      106.59412         210.82
# 2       Matt   Bullard  30.0      106.59412         208.28
# 3      Marty    Conlon  29.0      111.13004         210.82
# 4     Martin  Muursepp  22.0      106.59412         205.74
#
#                      college country   season  games_played  points  reb  \
# 0           Western Kentucky     USA  1996-97            41     4.6  1.7
# 1  North Carolina-Wilmington     USA  1996-97             6     0.3  0.8
# 2                       Iowa     USA  1996-97            71     4.5  1.6
# 3                 Providence     USA  1996-97            74     7.8  4.4
# 4                       None     USA  1996-97            42     3.7  1.6
#
#    assistance_pergame
# 0                 1.6
# 1                 0.0
# 2                 0.9
# 3                 1.4
# 4                 0.5
